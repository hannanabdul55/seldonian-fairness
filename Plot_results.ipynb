# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pickle

# %%
res = pickle.load(open('./results_3/final_res_p_results-1602387668.337485.p', 'rb'))

# %%
res_2 = pickle.load(open('./results_3/final_res_p_results-1602420536.692298.p', 'rb'))

# %%
res_2.append(res)
res_2
# Out:
# [{'N': 100,
#   'opt': ['Powell'],
#   'failure_rate': 0.0,
#   'failure_rate_std': 0.0,
#   'sol_found_rate': 0.9,
#   'sol_found_rate_std': 0.3,
#   'accuracy': 0.595,
#   'ghat': -0.12800000000000003,
#   'uc_failure_rate': 0.0,
#   'uc_failure_rate_std': 0.0,
#   'uc_accuracy': 0.74,
#   'uc_ghat': -0.04999999999999999},
#  {'N': 127,
#   'opt': ['Powell'],
#   'failure_rate': 0.0,
#   'failure_rate_std': 0.0,
#   'sol_found_rate': 0.7,
#   'sol_found_rate_std': 0.45825756949558394,
#   'accuracy': 0.5858267716535434,
#   'ghat': -0.1311023622047244,
#   'uc_failure_rate': 1.0,
#   'uc_failure_rate_std': 0.0,
#   'uc_accuracy': 0.6771653543307086,
#   'uc_ghat': 0.015354330708661407},
#  {'N': 162,
#   'opt': ['Powell'],
#   'failure_rate': 0.0,
#   'failure_rate_std': 0.0,
#   'sol_found_rate': 0.7,
#   'sol_found_rate_std': 0.45825756949558394,
#   'accuracy': 0.578395061728395,
#   'ghat': -0.13765432098765434,
#   'uc_failure_rate': 0.0,
#   'uc_failure_rate_std': 0.0,
#   'uc_accuracy': 0.6604938271604939,
#   'uc_ghat': -0.008024691358024694},
#  {'N': 208,
#   'opt': ['Powell'],
#   'failure_rate': 0.0,
#   'failure_rate_std': 0.0,
#   'sol_found_rate': 1.0,
#   'sol_found_rate_std': 0.0,
#   'accuracy': 0.5278846153846153,
#   'ghat': -0.1264423076923077,
#   'uc_failure_rate': 0.0,
#   'uc_failure_rate_std': 0.0,
#   'uc_accuracy': 0.6057692307692307,
#   'uc_ghat': -0.024999999999999994},
#  {'N': 265,
#   'opt': ['Powell'],
#   'failure_rate': 0.0,
#   'failure_rate_std': 0.0,
#   'sol_found_rate': 0.9,
#   'sol_found_rate_std': 0.30000000000000004,
#   'accuracy': 0.5211320754716982,
#   'ghat': -0.1220754716981132,
#   'uc_failure_rate': 0.0,
#   'uc_failure_rate_std': 0.0,
#   'uc_accuracy': 0.6037735849056604,
#   'uc_ghat': -0.033018867924528295},
#  {'N': 338,
#   'opt': ['Powell'],
#   'failure_rate': 0.0,
#   'failure_rate_std': 0.0,
#   'sol_found_rate': 0.6,
#   'sol_found_rate_std': 0.48989794855663565,
#   'accuracy': 0.4905325443786982,
#   'ghat': -0.12426035502958581,
#   'uc_failure_rate': 1.0,
#   'uc_failure_rate_std': 0.0,
#   'uc_accuracy': 0.6094674556213018,
#   'uc_ghat': 0.02159763313609467},
#  {'N': 432,
#   'opt': ['Powell'],
#   'failure_rate': 0.0,
#   'failure_rate_std': 0.0,
#   'sol_found_rate': 1.0,
#   'sol_found_rate_std': 0.0,
#   'accuracy': 0.5365740740740741,
#   'ghat': -0.1400462962962963,
#   'uc_failure_rate': 1.0,
#   'uc_failure_rate_std': 0.0,
#   'uc_accuracy': 0.6157407407407407,
#   'uc_ghat': 0.04907407407407407},
#  {'N': 552,
#   'opt': ['Powell'],
#   'failure_rate': 0.0,
#   'failure_rate_std': 0.0,
#   'sol_found_rate': 1.0,
#   'sol_found_rate_std': 0.0,
#   'accuracy': 0.5643115942028986,
#   'ghat': -0.1286231884057971,
#   'uc_failure_rate': 1.0,
#   'uc_failure_rate_std': 0.0,
#   'uc_accuracy': 0.6177536231884059,
#   'uc_ghat': 0.027536231884057988},
#  {'N': 705,
#   'opt': ['Powell'],
#   'failure_rate': 0.0,
#   'failure_rate_std': 0.0,
#   'sol_found_rate': 1.0,
#   'sol_found_rate_std': 0.0,
#   'accuracy': 0.5880851063829787,
#   'ghat': -0.10900709219858155,
#   'uc_failure_rate': 1.0,
#   'uc_failure_rate_std': 0.0,
#   'uc_accuracy': 0.5957446808510639,
#   'uc_ghat': 0.06134751773049647},
#  {'N': 899,
#   'opt': ['Powell'],
#   'failure_rate': 0.0,
#   'failure_rate_std': 0.0,
#   'sol_found_rate': 1.0,
#   'sol_found_rate_std': 0.0,
#   'accuracy': 0.5925472747497219,
#   'ghat': -0.08781979977753057,
#   'uc_failure_rate': 1.0,
#   'uc_failure_rate_std': 0.0,
#   'uc_accuracy': 0.6028921023359288,
#   'uc_ghat': 0.10139043381535037},
#  [{'N': 1000,
#    'opt': ['Powell'],
#    'failure_rate': 0.0,
#    'failure_rate_std': 0.0,
#    'sol_found_rate': 1.0,
#    'sol_found_rate_std': 0.0,
#    'accuracy': 0.5975999999999999,
#    'ghat': -0.0658,
#    'uc_failure_rate': 1.0,
#    'uc_failure_rate_std': 0.0,
#    'uc_accuracy': 0.617,
#    'uc_ghat': 0.10700000000000001},
#   {'N': 1438,
#    'opt': ['Powell'],
#    'failure_rate': 0.0,
#    'failure_rate_std': 0.0,
#    'sol_found_rate': 1.0,
#    'sol_found_rate_std': 0.0,
#    'accuracy': 0.6109179415855355,
#    'ghat': -0.07343532684283727,
#    'uc_failure_rate': 1.0,
#    'uc_failure_rate_std': 0.0,
#    'uc_accuracy': 0.6293463143254521,
#    'uc_ghat': 0.1309457579972184},
#   {'N': 2069,
#    'opt': ['Powell'],
#    'failure_rate': 0.0,
#    'failure_rate_std': 0.0,
#    'sol_found_rate': 1.0,
#    'sol_found_rate_std': 0.0,
#    'accuracy': 0.6243595940067665,
#    'ghat': -0.07595456742387627,
#    'uc_failure_rate': 1.0,
#    'uc_failure_rate_std': 0.0,
#    'uc_accuracy': 0.6336394393426776,
#    'uc_ghat': 0.14821169647172547},
#   {'N': 2976,
#    'opt': ['Powell'],
#    'failure_rate': 0.0,
#    'failure_rate_std': 0.0,
#    'sol_found_rate': 1.0,
#    'sol_found_rate_std': 0.0,
#    'accuracy': 0.6202284946236559,
#    'ghat': -0.054905913978494626,
#    'uc_failure_rate': 1.0,
#    'uc_failure_rate_std': 0.0,
#    'uc_accuracy': 0.6374327956989247,
#    'uc_ghat': 0.14939516129032257},
#   {'N': 4281,
#    'opt': ['Powell'],
#    'failure_rate': 0.0,
#    'failure_rate_std': 0.0,
#    'sol_found_rate': 1.0,
#    'sol_found_rate_std': 0.0,
#    'accuracy': 0.6017285680915674,
#    'ghat': -0.04352954917075449,
#    'uc_failure_rate': 1.0,
#    'uc_failure_rate_std': 0.0,
#    'uc_accuracy': 0.6535856108385891,
#    'uc_ghat': 0.1588063536556879},
#   {'N': 6158,
#    'opt': ['Powell'],
#    'failure_rate': 0.0,
#    'failure_rate_std': 0.0,
#    'sol_found_rate': 1.0,
#    'sol_found_rate_std': 0.0,
#    'accuracy': 0.6128126014939916,
#    'ghat': -0.03385839558298149,
#    'uc_failure_rate': 1.0,
#    'uc_failure_rate_std': 0.0,
#    'uc_accuracy': 0.6539460863916855,
#    'uc_ghat': 0.1541571938941215},
#   {'N': 8858,
#    'opt': ['Powell'],
#    'failure_rate': 0.0,
#    'failure_rate_std': 0.0,
#    'sol_found_rate': 1.0,
#    'sol_found_rate_std': 0.0,
#    'accuracy': 0.6342515240460601,
#    'ghat': -0.04677128019869045,
#    'uc_failure_rate': 1.0,
#    'uc_failure_rate_std': 0.0,
#    'uc_accuracy': 0.6522917137051253,
#    'uc_ghat': 0.1533416121020546},
#   {'N': 12742,
#    'opt': ['Powell'],
#    'failure_rate': 0.0,
#    'failure_rate_std': 0.0,
#    'sol_found_rate': 1.0,
#    'sol_found_rate_std': 0.0,
#    'accuracy': 0.6136085386909435,
#    'ghat': -0.027570240150682778,
#    'uc_failure_rate': 1.0,
#    'uc_failure_rate_std': 0.0,
#    'uc_accuracy': 0.6532726416575106,
#    'uc_ghat': 0.15073771778370745},
#   {'N': 18329,
#    'opt': ['Powell'],
#    'failure_rate': 0.0,
#    'failure_rate_std': 0.0,
#    'sol_found_rate': 1.0,
#    'sol_found_rate_std': 0.0,
#    'accuracy': 0.6141688035353812,
#    'ghat': -0.020254787495226138,
#    'uc_failure_rate': 1.0,
#    'uc_failure_rate_std': 0.0,
#    'uc_accuracy': 0.6496262753014348,
#    'uc_ghat': 0.14957990070380273},
#   {'N': 26366,
#    'opt': ['Powell'],
#    'failure_rate': 0.0,
#    'failure_rate_std': 0.0,
#    'sol_found_rate': 1.0,
#    'sol_found_rate_std': 0.0,
#    'accuracy': 0.6116020632632936,
#    'ghat': -0.017037093226124546,
#    'uc_failure_rate': 1.0,
#    'uc_failure_rate_std': 0.0,
#    'uc_accuracy': 0.6497003716908141,
#    'uc_ghat': 0.14917317757718276},
#   {'N': 37926,
#    'opt': ['Powell'],
#    'failure_rate': 0.0,
#    'failure_rate_std': 0.0,
#    'sol_found_rate': 1.0,
#    'sol_found_rate_std': 0.0,
#    'accuracy': 0.6138717502504878,
#    'ghat': -0.013853293255286609,
#    'uc_failure_rate': 1.0,
#    'uc_failure_rate_std': 0.0,
#    'uc_accuracy': 0.6487106470495175,
#    'uc_ghat': 0.1482386753150873},
#   {'N': 54555,
#    'opt': ['Powell'],
#    'failure_rate': 0.0,
#    'failure_rate_std': 0.0,
#    'sol_found_rate': 0.0,
#    'sol_found_rate_std': 0.0,
#    'accuracy': 0.6069929429016588,
#    'ghat': -0.0068197232151040125,
#    'uc_failure_rate': 1.0,
#    'uc_failure_rate_std': 0.0,
#    'uc_accuracy': 0.6498396114013382,
#    'uc_ghat': 0.14955091192374664},
#   {'N': 78475,
#    'opt': ['Powell'],
#    'failure_rate': 0.0,
#    'failure_rate_std': 0.0,
#    'sol_found_rate': 0.9,
#    'sol_found_rate_std': 0.30000000000000004,
#    'accuracy': 0.6048869066581714,
#    'ghat': -0.008642879898056701,
#    'uc_failure_rate': 1.0,
#    'uc_failure_rate_std': 0.0,
#    'uc_accuracy': 0.6488180949346926,
#    'uc_ghat': 0.1496113411914623},
#   {'N': 112883,
#    'opt': ['Powell'],
#    'failure_rate': 0.0,
#    'failure_rate_std': 0.0,
#    'sol_found_rate': 0.7,
#    'sol_found_rate_std': 0.45825756949558394,
#    'accuracy': 0.6008008291771125,
#    'ghat': -0.00686861617781242,
#    'uc_failure_rate': 1.0,
#    'uc_failure_rate_std': 0.0,
#    'uc_accuracy': 0.6486007636225118,
#    'uc_ghat': 0.15036409379623156},
#   {'N': 162377,
#    'opt': ['Powell'],
#    'failure_rate': 0.0,
#    'failure_rate_std': 0.0,
#    'sol_found_rate': 1.0,
#    'sol_found_rate_std': 0.0,
#    'accuracy': 0.6066148530887996,
#    'ghat': -0.00698898242977761,
#    'uc_failure_rate': 1.0,
#    'uc_failure_rate_std': 0.0,
#    'uc_accuracy': 0.6506340183646698,
#    'uc_ghat': 0.15110791552990882},
#   {'N': 233572,
#    'opt': ['Powell'],
#    'failure_rate': 0.0,
#    'failure_rate_std': 0.0,
#    'sol_found_rate': 1.0,
#    'sol_found_rate_std': 0.0,
#    'accuracy': 0.6052660421625881,
#    'ghat': -0.006740533968112611,
#    'uc_failure_rate': 1.0,
#    'uc_failure_rate_std': 0.0,
#    'uc_accuracy': 0.6506045245149249,
#    'uc_ghat': 0.15076807151542135},
#   {'N': 335981,
#    'opt': ['Powell'],
#    'failure_rate': 0.0,
#    'failure_rate_std': 0.0,
#    'sol_found_rate': 1.0,
#    'sol_found_rate_std': 0.0,
#    'accuracy': 0.5981341206794432,
#    'ghat': -0.004239078995538437,
#    'uc_failure_rate': 1.0,
#    'uc_failure_rate_std': 0.0,
#    'uc_accuracy': 0.6511856325208865,
#    'uc_ghat': 0.1515081209949372},
#   {'N': 483293,
#    'opt': ['Powell'],
#    'failure_rate': 0.0,
#    'failure_rate_std': 0.0,
#    'sol_found_rate': 1.0,
#    'sol_found_rate_std': 0.0,
#    'accuracy': 0.59893729062908,
#    'ghat': -0.0035567450801066796,
#    'uc_failure_rate': 1.0,
#    'uc_failure_rate_std': 0.0,
#    'uc_accuracy': 0.6502039135679599,
#    'uc_ghat': 0.15057128905239675},
#   {'N': 695192,
#    'opt': ['Powell'],
#    'failure_rate': 0.0,
#    'failure_rate_std': 0.0,
#    'sol_found_rate': 0.9,
#    'sol_found_rate_std': 0.3,
#    'accuracy': 0.6043055731366299,
#    'ghat': -0.003200266976605018,
#    'uc_failure_rate': 1.0,
#    'uc_failure_rate_std': 0.0,
#    'uc_accuracy': 0.650391546508015,
#    'uc_ghat': 0.15045368761435693},
#   {'N': 1000000,
#    'opt': ['Powell'],
#    'failure_rate': 0.0,
#    'failure_rate_std': 0.0,
#    'sol_found_rate': 1.0,
#    'sol_found_rate_std': 0.0,
#    'accuracy': 0.6052848,
#    'ghat': -0.002376699999999993,
#    'uc_failure_rate': 1.0,
#    'uc_failure_rate_std': 0.0,
#    'uc_accuracy': 0.6496130000000001,
#    'uc_ghat': 0.15013800000000005}]]

# %%
x_arr = [x['N'] for x in res_2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-7c9917e62241> in <module>
# ----> 1 x_arr = [x['N'] for x in res_2]
#
# <ipython-input-5-7c9917e62241> in <listcomp>(.0)
# ----> 1 x_arr = [x['N'] for x in res_2]
#
# TypeError: list indices must be integers or slices, not str

# %%
x_arr = np.linspace(5000, 100000, 20).astype(np.int)

for opt in res:
    x = x_arr[:len(res[opt])]
    ghat_c = []
    ghat_uc = []

    fr_c = []
    fr_c_std = []
    fr_uc = []
    fr_uc_std = []

    acc_c = []
    acc_uc = []
    for r in res[opt]:
        fr_c.append(r['failure_rate'])
        fr_uc.append(r['uc_failure_rate'])
        
        fr_c_std.append(r['failure_rate_std'])
        fr_uc_std.append(r['uc_failure_rate_std'])
        
        acc_c.append(r['accuracy'])
        acc_uc.append(r['uc_accuracy'])

        ghat_c.append(r['ghat'])
        ghat_uc.append(r['uc_ghat'])
        
    plt.plot(x, fr_c, label='Constrained failure rate')
    plt.plot(x, fr_uc, label='Unconstrained failure rate')
    plt.xlabel('Number of data points')
    plt.ylabel('failure rate')
    plt.legend()
    plt.title(f"[{opt}]Plot for number of data points vs failure rate")
    plt.show()
    
    plt.plot(x, ghat_c, label='Constrained ghat')
    plt.plot(x, ghat_uc, label='Unconstrained ghat')
    plt.xlabel('Number of data points')
    plt.ylabel('mean ghat')
    plt.legend()
    plt.title(f"[{opt}]Plot for number of data points vs mean ghat")
    plt.show()
    
    plt.plot(x, acc_c, label='Constrained accuracy')
    plt.plot(x, acc_uc, label='Unconstrained accuracy')
    plt.xlabel('Number of data points')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.title(f"[{opt}]Plot for number of data points vs accuracy")
    plt.show()

# %%
len(res['CMAES'])

# %%
x = np.linspace(500, 100000, 10).astype(np.int)
ghat_c = []
ghat_uc = []

fr_c = []
fr_uc = []

acc_c = []
acc_uc = []
for r in res:
    fr_c.append(r['failure_rate'])
    fr_uc.append(r['uc_failure_rate'])
    
    acc_c.append(r['accuracy'])
    acc_uc.append(r['uc_accuracy'])
plt.plot(x, fr_c, label='Constrained failure rate')
plt.plot(x, fr_uc, label='Unconstrained failure rate')
plt.xlabel('Number of data points')
plt.ylabel('failure rate')
plt.legend()
plt.title('Plot for number of data points vs failure rate')
plt.show()
plt.plot(x, acc_c, label='Constrained accuracy')
plt.plot(x, acc_uc, label='Unconstrained accuracy')
plt.xlabel('Number of data points')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Plot for number of data points vs accuracy')
plt.show()
