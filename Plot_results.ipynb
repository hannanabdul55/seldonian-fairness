# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pickle

# %%
res
# Out:
# {'Powell': [{'failure_rate': 0.0,
#    'failure_rate_std': 0.0,
#    'accuracy': 0.58436,
#    'ghat': 0.0,
#    'uc_failure_rate': 1.0,
#    'uc_failure_rate_std': 0.0,
#    'uc_accuracy': 0.6522000000000001,
#    'uc_ghat': 0.16409602147986996},
#   {'failure_rate': 0.15,
#    'failure_rate_std': 0.3570714214271425,
#    'accuracy': 0.58442,
#    'ghat': 0.0017310021315346106,
#    'uc_failure_rate': 1.0,
#    'uc_failure_rate_std': 0.0,
#    'uc_accuracy': 0.6516,
#    'uc_ghat': 0.15904908575081306},
#   {'failure_rate': 0.0,
#    'failure_rate_std': 0.0,
#    'accuracy': 0.5991333333333333,
#    'ghat': 0.0,
#    'uc_failure_rate': 1.0,
#    'uc_failure_rate_std': 0.0,
#    'uc_accuracy': 0.6527999999999998,
#    'uc_ghat': 0.15749597691894462},
#   {'failure_rate': 0.85,
#    'failure_rate_std': 0.3570714214271425,
#    'accuracy': 0.6046750000000001,
#    'ghat': 0.0033803033649897297,
#    'uc_failure_rate': 1.0,
#    'uc_failure_rate_std': 0.0,
#    'uc_accuracy': 0.6511499999999999,
#    'uc_ghat': 0.15432509033793218},
#   {'failure_rate': 1.0,
#    'failure_rate_std': 0.0,
#    'accuracy': 0.60774,
#    'ghat': 0.005243653173636941,
#    'uc_failure_rate': 1.0,
#    'uc_failure_rate_std': 0.0,
#    'uc_accuracy': 0.6498799999999999,
#    'uc_ghat': 0.15460668857656873},
#   {'failure_rate': 1.0,
#    'failure_rate_std': 0.0,
#    'accuracy': 0.60794,
#    'ghat': 0.0052987907812836145,
#    'uc_failure_rate': 1.0,
#    'uc_failure_rate_std': 0.0,
#    'uc_accuracy': 0.6488666666666667,
#    'uc_ghat': 0.15324743384418477},
#   {'failure_rate': 0.95,
#    'failure_rate_std': 0.21794494717703367,
#    'accuracy': 0.6037957142857142,
#    'ghat': 0.0045557968679845046,
#    'uc_failure_rate': 1.0,
#    'uc_failure_rate_std': 0.0,
#    'uc_accuracy': 0.6486285714285713,
#    'uc_ghat': 0.15285321935853202},
#   {'failure_rate': 0.9,
#    'failure_rate_std': 0.30000000000000004,
#    'accuracy': 0.6059962500000001,
#    'ghat': 0.002963841591484434,
#    'uc_failure_rate': 1.0,
#    'uc_failure_rate_std': 0.0,
#    'uc_accuracy': 0.6477000000000002,
#    'uc_ghat': 0.15108424200321832}],
#  'CMAES': [{'failure_rate': 1.0,
#    'failure_rate_std': 0.0,
#    'accuracy': 0.59643,
#    'ghat': 0.012636514896697513,
#    'uc_failure_rate': 1.0,
#    'uc_failure_rate_std': 0.0,
#    'uc_accuracy': 0.6522000000000001,
#    'uc_ghat': 0.16409602147986996},
#   {'failure_rate': 0.85,
#    'failure_rate_std': 0.3570714214271425,
#    'accuracy': 0.59903,
#    'ghat': 0.0057415104257167214,
#    'uc_failure_rate': 1.0,
#    'uc_failure_rate_std': 0.0,
#    'uc_accuracy': 0.6516,
#    'uc_ghat': 0.15904908575081306},
#   {'failure_rate': 0.0,
#    'failure_rate_std': 0.0,
#    'accuracy': 0.6010766666666666,
#    'ghat': 0.0,
#    'uc_failure_rate': 1.0,
#    'uc_failure_rate_std': 0.0,
#    'uc_accuracy': 0.6527999999999998,
#    'uc_ghat': 0.15749597691894462},
#   {'failure_rate': 1.0,
#    'failure_rate_std': 0.0,
#    'accuracy': 0.6025025,
#    'ghat': 0.009058781988513436,
#    'uc_failure_rate': 1.0,
#    'uc_failure_rate_std': 0.0,
#    'uc_accuracy': 0.6511499999999999,
#    'uc_ghat': 0.15432509033793218},
#   {'failure_rate': 1.0,
#    'failure_rate_std': 0.0,
#    'accuracy': 0.6001580000000001,
#    'ghat': 0.005849912215229097,
#    'uc_failure_rate': 1.0,
#    'uc_failure_rate_std': 0.0,
#    'uc_accuracy': 0.6498799999999999,
#    'uc_ghat': 0.15460668857656873},
#   {'failure_rate': 1.0,
#    'failure_rate_std': 0.0,
#    'accuracy': 0.6011183333333334,
#    'ghat': 0.012358662655071994,
#    'uc_failure_rate': 1.0,
#    'uc_failure_rate_std': 0.0,
#    'uc_accuracy': 0.6488666666666667,
#    'uc_ghat': 0.15324743384418477},
#   {'failure_rate': 1.0,
#    'failure_rate_std': 0.0,
#    'accuracy': 0.60161,
#    'ghat': 0.010133102046249818,
#    'uc_failure_rate': 1.0,
#    'uc_failure_rate_std': 0.0,
#    'uc_accuracy': 0.6486285714285713,
#    'uc_ghat': 0.15285321935853202}]}

# %%
res = pickle.load(open('./results_2/results-1602274810.302946.p', 'rb'))
x_arr = np.linspace(5000, 100000, 20).astype(np.int)

for opt in res:
    x = x_arr[:len(res[opt])]
    ghat_c = []
    ghat_uc = []

    fr_c = []
    fr_c_std = []
    fr_uc = []
    fr_uc_std = []

    acc_c = []
    acc_uc = []
    for r in res[opt]:
        fr_c.append(r['failure_rate'])
        fr_uc.append(r['uc_failure_rate'])
        
        fr_c_std.append(r['failure_rate_std'])
        fr_uc_std.append(r['uc_failure_rate_std'])
        
        acc_c.append(r['accuracy'])
        acc_uc.append(r['uc_accuracy'])

        ghat_c.append(r['ghat'])
        ghat_uc.append(r['uc_ghat'])
        
    plt.plot(x, fr_c, label='Constrained failure rate')
    plt.plot(x, fr_uc, label='Unconstrained failure rate')
    plt.xlabel('Number of data points')
    plt.ylabel('failure rate')
    plt.legend()
    plt.title(f"[{opt}]Plot for number of data points vs failure rate")
    plt.show()
    
    plt.plot(x, ghat_c, label='Constrained ghat')
    plt.plot(x, ghat_uc, label='Unconstrained ghat')
    plt.xlabel('Number of data points')
    plt.ylabel('mean ghat')
    plt.legend()
    plt.title(f"[{opt}]Plot for number of data points vs mean ghat")
    plt.show()
    
    plt.plot(x, acc_c, label='Constrained accuracy')
    plt.plot(x, acc_uc, label='Unconstrained accuracy')
    plt.xlabel('Number of data points')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.title(f"[{opt}]Plot for number of data points vs accuracy")
    plt.show()

# %%
len(res['CMAES'])
# Out:
# 7

# %%
x = np.linspace(500, 100000, 10).astype(np.int)
ghat_c = []
ghat_uc = []

fr_c = []
fr_uc = []

acc_c = []
acc_uc = []
for r in res:
    fr_c.append(r['failure_rate'])
    fr_uc.append(r['uc_failure_rate'])
    
    acc_c.append(r['accuracy'])
    acc_uc.append(r['uc_accuracy'])
plt.plot(x, fr_c, label='Constrained failure rate')
plt.plot(x, fr_uc, label='Unconstrained failure rate')
plt.xlabel('Number of data points')
plt.ylabel('failure rate')
plt.legend()
plt.title('Plot for number of data points vs failure rate')
plt.show()
plt.plot(x, acc_c, label='Constrained accuracy')
plt.plot(x, acc_uc, label='Unconstrained accuracy')
plt.xlabel('Number of data points')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Plot for number of data points vs accuracy')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-33f8cf536a41> in <module>
#       9 acc_uc = []
#      10 for r in res:
# ---> 11     fr_c.append(r['failure_rate'])
#      12     fr_uc.append(r['uc_failure_rate'])
#      13
#
# TypeError: string indices must be integers
