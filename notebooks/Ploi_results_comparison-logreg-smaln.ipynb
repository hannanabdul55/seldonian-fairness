# %%
# %cd ..
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pickle
import glob
from experiment.plot_results import *
# Out:
# /Users/abdulhannankanji/Documents/GitHub/seldonian-fairness

# %% [markdown]
# # Plot comparison

# %%
print_config=True
folders = ['result/result_logreg_small_n_strat_dryrun_2','result/result_logreg_small_n_nostrat_dryrun_2']
fig, axs = plt.subplots(4,len(folders), figsize=(13, int(13*4/len(folders))), sharey=True, gridspec_kw={'hspace':0.3},
                       constrained_layout=True)
axs = np.array(axs).reshape(4, len(folders))
figtitle = "Comparison "
for i in range(len(folders)):
    config = pickle.load(open(folders[i] + "/config.p", "rb"))
    if print_config:
        print(config)
    exps = pickle.load(open(folders[i] + "/exps.p", "rb"))
    res = pickle.load(open(list(glob.glob(folders[i] + '/final_res*.p'))[0], 'rb'))
    plot_results(res, config['name'], axs = axs[:,i])
    figtitle+= f"- {config['name']}"
fig.suptitle(figtitle)
plt.show()
# Out:
# {'name': 'logreg_small_n_strat_dryrun_2', 'N': [312.42424242, 362.82828283, 413.23232323, 463.63636364, 514.04040404, 564.44444444, 614.84848485, 665.25252525, 715.65656566, 766.06060606, 816.46464646, 866.86868687, 917.27272727, 967.67676768, 1018.08080808, 1068.48484848, 1118.88888889, 1169.29292929, 1219.6969697, 1270.1010101, 1320.50505051, 1370.90909091, 1421.31313131, 1471.71717172, 1522.12121212, 1572.52525253, 1622.92929293, 1673.33333333, 1723.73737374, 1774.14141414, 1824.54545455, 1874.94949495, 1925.35353535, 1975.75757576, 2026.16161616, 2076.56565657, 2126.96969697, 2177.37373737, 2227.77777778, 2278.18181818, 2328.58585859, 2378.98989899, 2429.39393939, 2479.7979798, 2530.2020202, 2580.60606061, 2631.01010101, 2681.41414141, 2731.81818182, 2782.22222222, 2832.62626263, 2883.03030303, 2933.43434343, 2983.83838384, 3034.24242424, 3084.64646465, 3135.05050505, 3185.45454545, 3235.85858586, 3286.26262626, 3336.66666667, 3387.07070707, 3437.47474747, 3487.87878788, 3538.28282828, 3588.68686869, 3639.09090909, 3689.49494949, 3739.8989899, 3790.3030303, 3840.70707071, 3891.11111111, 3941.51515152, 3991.91919192, 4042.32323232, 4092.72727273, 4143.13131313, 4193.53535354, 4243.93939394, 4294.34343434, 4344.74747475, 4395.15151515, 4445.55555556, 4495.95959596, 4546.36363636, 4596.76767677, 4647.17171717, 4697.57575758, 4747.97979798, 4798.38383838, 4848.78787879, 4899.19191919, 4949.5959596, 5000], 'trials': 20, 'method': 'ttest', 'D': 5, 'tprs': [0.2, 0.9], 'test_size': 0.4, 'opt': 'Powell', 'stratify': True, 'hard_barrier': True, 'thetas': 10, 'thresh': 0.2}
# {'name': 'logreg_small_n_nostrat_dryrun_2', 'N': [312.42424242, 362.82828283, 413.23232323, 463.63636364, 514.04040404, 564.44444444, 614.84848485, 665.25252525, 715.65656566, 766.06060606, 816.46464646, 866.86868687, 917.27272727, 967.67676768, 1018.08080808, 1068.48484848, 1118.88888889, 1169.29292929, 1219.6969697, 1270.1010101, 1320.50505051, 1370.90909091, 1421.31313131, 1471.71717172, 1522.12121212, 1572.52525253, 1622.92929293, 1673.33333333, 1723.73737374, 1774.14141414, 1824.54545455, 1874.94949495, 1925.35353535, 1975.75757576, 2026.16161616, 2076.56565657, 2126.96969697, 2177.37373737, 2227.77777778, 2278.18181818, 2328.58585859, 2378.98989899, 2429.39393939, 2479.7979798, 2530.2020202, 2580.60606061, 2631.01010101, 2681.41414141, 2731.81818182, 2782.22222222, 2832.62626263, 2883.03030303, 2933.43434343, 2983.83838384, 3034.24242424, 3084.64646465, 3135.05050505, 3185.45454545, 3235.85858586, 3286.26262626, 3336.66666667, 3387.07070707, 3437.47474747, 3487.87878788, 3538.28282828, 3588.68686869, 3639.09090909, 3689.49494949, 3739.8989899, 3790.3030303, 3840.70707071, 3891.11111111, 3941.51515152, 3991.91919192, 4042.32323232, 4092.72727273, 4143.13131313, 4193.53535354, 4243.93939394, 4294.34343434, 4344.74747475, 4395.15151515, 4445.55555556, 4495.95959596, 4546.36363636, 4596.76767677, 4647.17171717, 4697.57575758, 4747.97979798, 4798.38383838, 4848.78787879, 4899.19191919, 4949.5959596, 5000], 'trials': 20, 'method': 'ttest', 'D': 5, 'tprs': [0.2, 0.9], 'test_size': 0.4, 'opt': 'Powell', 'stratify': False, 'hard_barrier': True, 'thetas': 10, 'thresh': 0.2}

# %%
print_config=True
folders = ['result/result_mc_nostrat_ttest_01_40trials_10theta', 'result/result_mc_strat_ttest_01_40trials_10theta'
    ,'result/result_mc_nostrat_ttest_05_40trials_10theta', 'result/result_mc_strat_ttest_05_40trials_10theta']
fig, axs = plt.subplots(4,len(folders), figsize=(13, int(13*4/len(folders))), sharey=True, gridspec_kw={'hspace':0.3},
                       constrained_layout=True)
axs = np.array(axs).reshape(4, len(folders))
figtitle = "Comparison "
for i in range(len(folders)):
    config = pickle.load(open(folders[i] + "/config.p", "rb"))
    if print_config:
        print(config)
    exps = pickle.load(open(folders[i] + "/exps.p", "rb"))
    res = pickle.load(open(list(glob.glob(folders[i] + '/final_res*.p'))[0], 'rb'))
    plot_results(res, config['name'], axs = axs[:,i])
    figtitle+= f"- {config['name']}"
fig.suptitle(figtitle)
plt.show()
# Out:
# {'name': 'mc_nostrat_ttest_05_40trials_10theta', 'N': [100.0, 137.38238, 188.739182, 259.29438, 356.224789, 489.390092, 672.335754, 923.670857, 1268.961, 1743.32882, 2395.02662, 3290.34456, 4520.35366, 6210.16942, 8531.67852, 11721.023, 16102.6203, 22122.1629, 30391.9538, 41753.1894, 57361.5251, 78804.6282, 108263.673, 148735.211, 204335.972, 280721.62, 385662.042, 529831.691, 727895.384, 1000000.0], 'trials': 30, 'method': 'ttest', 'D': 5, 'tprs': [0.1, 0.9], 'test_size': 0.2, 'opt': 'CMAES', 'stratify': False, 'thetas': 10, 'a_prob': 0.05}
# {'name': 'mc_strat_ttest_05_40trials_10theta', 'N': [100.0, 137.38238, 188.739182, 259.29438, 356.224789, 489.390092, 672.335754, 923.670857, 1268.961, 1743.32882, 2395.02662, 3290.34456, 4520.35366, 6210.16942, 8531.67852, 11721.023, 16102.6203, 22122.1629, 30391.9538, 41753.1894, 57361.5251, 78804.6282, 108263.673, 148735.211, 204335.972, 280721.62, 385662.042, 529831.691, 727895.384, 1000000.0], 'trials': 30, 'method': 'ttest', 'D': 5, 'tprs': [0.1, 0.9], 'test_size': 0.2, 'opt': 'CMAES', 'stratify': True, 'thetas': 10, 'a_prob': 0.05}
