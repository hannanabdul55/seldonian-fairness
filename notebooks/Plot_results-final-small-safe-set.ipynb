# %%
# %cd ..
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pickle
import glob
from experiment.plot_results import *
# Out:
# /Users/abdulhannan/PycharmProjects/seldonian

# %% [markdown]
# # CMA-ES run for 50 trials using Hoeffdings

# %%
folder = 'result/result_final_cmaes_hf_50tr_small_safe'

config = pickle.load(open(folder + "/config.p", "rb"))
exps = pickle.load(open(folder + "/exps.p", "rb"))
res = pickle.load(open(list(glob.glob(folder + '/final_res*.p'))[0], 'rb'))
plot_results(res, config['opt'])
print(config)
# Out:
# {'name': 'final_cmaes_hf_50tr_small_safe', 'N': [2395.02662, 3290.34456, 4520.35366, 6210.16942, 8531.67852, 11721.023, 16102.6203, 22122.1629, 30391.9538, 41753.1894, 57361.5251, 78804.6282, 108263.673, 148735.211, 204335.972, 280721.62, 385662.042, 529831.691, 727895.384, 1000000.0], 'trials': 50, 'method': 'hoeffdings', 'D': 5, 'tprs': [0.1, 0.9], 'test_size': 1000, 'opt': 'CMAES', 'hard_barrier': True, 'stratify': False}

# %% [markdown]
# # CMA-ES run with stratification using Hoeffings

# %%
folder = 'result/result_final_cmaes_hf_50tr_strat_small_safe'

config = pickle.load(open(folder + "/config.p", "rb"))
exps = pickle.load(open(folder + "/exps.p", "rb"))
res = pickle.load(open(list(glob.glob(folder + '/final_res*.p'))[0], 'rb'))
plot_results(res, config['opt'])
print(config)
# Out:
# {'name': 'final_cmaes_hf_50tr_strat_small_safe', 'N': [2395.02662, 3290.34456, 4520.35366, 6210.16942, 8531.67852, 11721.023, 16102.6203, 22122.1629, 30391.9538, 41753.1894, 57361.5251, 78804.6282, 108263.673, 148735.211, 204335.972, 280721.62, 385662.042, 529831.691, 727895.384, 1000000.0], 'trials': 50, 'method': 'hoeffdings', 'D': 5, 'tprs': [0.1, 0.9], 'test_size': 1000, 'opt': 'CMAES', 'hard_barrier': True, 'stratify': True}

# %% [markdown]
# # Powell results for 100 trials wiith hoeffings

# %%
folder = 'result/result_final_powell_100tr_30n_hf_v2'

config = pickle.load(open(folder + "/config.p", "rb"))
exps = pickle.load(open(folder + "/exps.p", "rb"))
res = pickle.load(open(list(glob.glob(folder + '/final_res*.p'))[0], 'rb'))
plot_results(res, config['opt'])

# %% [markdown]
# # Powell results for 100 trials with stratification

# %%
folder = 'result/result_final_powell_100tr_30n_hf_v2_strat'

config = pickle.load(open(folder + "/config.p", "rb"))
exps = pickle.load(open(folder + "/exps.p", "rb"))
# res = pickle.load(open(list(glob.glob(folder + '/final_res*.p'))[0], 'rb'))
plot_results(res, config['opt'])

# %% [markdown]
# # CMA-ES Soft barrier for 50 trials using Student's t-test

# %%
folder = 'result/result_final_soft_barrier_cmaes_ttest_50tr'

config = pickle.load(open(folder + "/config.p", "rb"))
exps = pickle.load(open(folder + "/exps.p", "rb"))
res = pickle.load(open(list(glob.glob(folder + '/final_res*.p'))[0], 'rb'))
plot_results(res, config['opt'])
