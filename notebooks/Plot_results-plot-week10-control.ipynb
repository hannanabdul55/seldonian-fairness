# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pickle
import glob
from experiment.plot_results import *

# %% [markdown]
# # V2 Powell parallel run with hard barrier with hoeffdings

# %%
folder = 'result/result_powell_30trials_hardbarrier_v2_week10'

config = pickle.load(open(folder + "/config.p", "rb"))
exps = pickle.load(open(folder + "/exps.p", "rb"))
res = pickle.load(open(list(glob.glob(folder + '/final_res*.p'))[0], 'rb'))
plot_results(res, config['opt'])

# %% [markdown]
# # Hard barrier powell for 30 trials with Hoeffdings

# %%
folder = 'result/result_powell_100tr_30n_stratify_hf'

config = pickle.load(open(folder + "/config.p", "rb"))
exps = pickle.load(open(folder + "/exps.p", "rb"))
res = pickle.load(open(list(glob.glob(folder + '/final_res*.p'))[0], 'rb'))
plot_results(res, config['opt'])

# %% [markdown]
# # Powell soft barrier

# %%
folder = 'result/result_powell_100tr_30n_stratify_hf'

config = pickle.load(open(folder + "/config.p", "rb"))
exps = pickle.load(open(folder + "/exps.p", "rb"))
res = pickle.load(open(list(glob.glob(folder + '/final_res*.p'))[0], 'rb'))
plot_results(res, config['opt'])

# %% [markdown]
# # CMAES results

# %%
folder = 'result/result_cmaes_50tr_hardbarrier_hf'

config = pickle.load(open(folder + "/config.p", "rb"))
exps = pickle.load(open(folder + "/exps.p", "rb"))
# res = pickle.load(open(list(glob.glob(folder + '/final_res*.p'))[0], 'rb'))
plot_results(res, config['opt'])

# %% [markdown]
# # CMA-ES Hardbarrier week7 for 50 trials with stratification

# %%
folder = 'result/result_cmaes_50tr_stratify_hardbarrier_hf'

config = pickle.load(open(folder + "/config.p", "rb"))
exps = pickle.load(open(folder + "/exps.p", "rb"))
res = pickle.load(open(list(glob.glob(folder + '/final_res*.p'))[0], 'rb'))
plot_results(res, config['opt'])
