# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pickle
import glob
from experiment.plot_results import *

# %% [markdown]
# # V2 Powell parallel run with hard barrier with hoeffdings

# %%
folder = 'result/result_week12_powell_ttest_dummy'

config = pickle.load(open(folder + "/config.p", "rb"))
exps = pickle.load(open(folder + "/exps.p", "rb"))
res = pickle.load(open(list(glob.glob(folder + '/final_res*.p'))[0], 'rb'))
plot_results(res, config['opt'])

# %% [markdown]
# # Hard barrier powell for 30 trials with Hoeffdings and stratification

# %%
folder = 'result/result_week12_powell_ttest_strat_dummy'

config = pickle.load(open(folder + "/config.p", "rb"))
exps = pickle.load(open(folder + "/exps.p", "rb"))
res = pickle.load(open(list(glob.glob(folder + '/final_res*.p'))[0], 'rb'))
plot_results(res, config['opt'])

# %% [markdown]
# # CMAES results

# %%
folder = 'result/result_week11_cmaes_hf_50tr'

config = pickle.load(open(folder + "/config.p", "rb"))
exps = pickle.load(open(folder + "/exps.p", "rb"))
# res = pickle.load(open(list(glob.glob(folder + '/final_res*.p'))[0], 'rb'))
plot_results(res, config['opt'])

# %% [markdown]
# # CMA-ES Hardbarrier week7 for 50 trials with stratification and Hoeffding's bound

# %%
folder = 'result/result_week11_cmaes_hf_50tr_stratcmae'

config = pickle.load(open(folder + "/config.p", "rb"))
exps = pickle.load(open(folder + "/exps.p", "rb"))
res = pickle.load(open(list(glob.glob(folder + '/final_res*.p'))[0], 'rb'))
plot_results(res, config['opt'])

# %% [markdown]
# # Powell run with 50 trials

# %%
folder = 'result/result_week12_powell_20tr_30n_ttest_v2'
    
config = pickle.load(open(folder + "/config.p", "rb"))
exps = pickle.load(open(folder + "/exps.p", "rb"))
res = pickle.load(open(list(glob.glob(folder + '/final_res*.p'))[0], 'rb'))
plot_results(res, config['opt'])

# %% [markdown]
# # Powell run 20 trials with stratifacation

# %%
folder = 'result/result_week12_powell_20tr_30n_ttest_v2_strat'

config = pickle.load(open(folder + "/config.p", "rb"))
exps = pickle.load(open(folder + "/exps.p", "rb"))
res = pickle.load(open(list(glob.glob(folder + '/final_res*.p'))[0], 'rb'))
plot_results(res, config['opt'])
