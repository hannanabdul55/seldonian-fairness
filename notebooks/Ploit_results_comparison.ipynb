# %%
# %cd ..
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pickle
import glob
from experiment.plot_results import *
# Out:
# /Users/abdulhannan/PycharmProjects/seldonian

# %% [markdown]
# # Plot comparison

# %%
print_config=True
folders = ['result/result_mc_nostrat_ttest_001_hb','result/result_mc_strat_ttest_001_hb',
           'result/result_mc_strat_ttest_001']
fig, axs = plt.subplots(4,len(folders), figsize=(13, int(13*4/len(folders))), sharey=True, gridspec_kw={'hspace':0.3},
                       constrained_layout=True)
axs = np.array(axs).reshape(4, len(folders))
figtitle = "Comparison "
for i in range(len(folders)):
    config = pickle.load(open(folders[i] + "/config.p", "rb"))
    if print_config:
        print(config)
    exps = pickle.load(open(folders[i] + "/exps.p", "rb"))
    res = pickle.load(open(list(glob.glob(folders[i] + '/final_res*.p'))[0], 'rb'))
    plot_results(res, config['name'], axs = axs[:,i])
    figtitle+= f"- {config['name']}"
fig.suptitle(figtitle)
plt.show()
# Out:
# {'name': 'mc_nostrat_ttest_001_hb', 'N': [100.0, 137.38238, 188.739182, 259.29438, 356.224789, 489.390092, 672.335754, 923.670857, 1268.961, 1743.32882, 2395.02662, 3290.34456, 4520.35366, 6210.16942, 8531.67852, 11721.023, 16102.6203, 22122.1629, 30391.9538, 41753.1894, 57361.5251, 78804.6282, 108263.673, 148735.211, 204335.972, 280721.62, 385662.042, 529831.691, 727895.384, 1000000.0], 'trials': 30, 'method': 'ttest', 'D': 5, 'tprs': [0.1, 0.9], 'test_size': 0.2, 'opt': 'CMAES', 'stratify': False, 'hard_barrier': True, 'thetas': 10, 'a_prob': 0.01}
# {'name': 'mc_strat_ttest_001_hb', 'N': [100.0, 137.38238, 188.739182, 259.29438, 356.224789, 489.390092, 672.335754, 923.670857, 1268.961, 1743.32882, 2395.02662, 3290.34456, 4520.35366, 6210.16942, 8531.67852, 11721.023, 16102.6203, 22122.1629, 30391.9538, 41753.1894, 57361.5251, 78804.6282, 108263.673, 148735.211, 204335.972, 280721.62, 385662.042, 529831.691, 727895.384, 1000000.0], 'trials': 30, 'method': 'ttest', 'D': 5, 'tprs': [0.1, 0.9], 'test_size': 0.2, 'opt': 'CMAES', 'stratify': True, 'hard_barrier': True, 'thetas': 10, 'a_prob': 0.01}
# {'name': 'mc_strat_ttest_001', 'N': [100.0, 137.38238, 188.739182, 259.29438, 356.224789, 489.390092, 672.335754, 923.670857, 1268.961, 1743.32882, 2395.02662, 3290.34456, 4520.35366, 6210.16942, 8531.67852, 11721.023, 16102.6203, 22122.1629, 30391.9538, 41753.1894, 57361.5251, 78804.6282, 108263.673, 148735.211, 204335.972, 280721.62, 385662.042, 529831.691, 727895.384, 1000000.0], 'trials': 30, 'method': 'ttest', 'D': 5, 'tprs': [0.1, 0.9], 'test_size': 0.2, 'opt': 'CMAES', 'stratify': True, 'hard_barrier': False, 'thetas': 10, 'a_prob': 0.01}

# %%
print_config=True
folders = ['result/result_mc_nostrat_ttest_01_40trials_10theta', 'result/result_mc_strat_ttest_01_40trials_10theta'
    ,'result/result_mc_nostrat_ttest_05_40trials_10theta', 'result/result_mc_strat_ttest_05_40trials_10theta']
fig, axs = plt.subplots(4,len(folders), figsize=(13, int(13*4/len(folders))), sharey=True, gridspec_kw={'hspace':0.3},
                       constrained_layout=True)
axs = np.array(axs).reshape(4, len(folders))
figtitle = "Comparison "
for i in range(len(folders)):
    config = pickle.load(open(folders[i] + "/config.p", "rb"))
    if print_config:
        print(config)
    exps = pickle.load(open(folders[i] + "/exps.p", "rb"))
    res = pickle.load(open(list(glob.glob(folders[i] + '/final_res*.p'))[0], 'rb'))
    plot_results(res, config['name'], axs = axs[:,i])
    figtitle+= f"- {config['name']}"
fig.suptitle(figtitle)
plt.show()
# Out:
# {'name': 'mc_nostrat_ttest_05_40trials_10theta', 'N': [100.0, 137.38238, 188.739182, 259.29438, 356.224789, 489.390092, 672.335754, 923.670857, 1268.961, 1743.32882, 2395.02662, 3290.34456, 4520.35366, 6210.16942, 8531.67852, 11721.023, 16102.6203, 22122.1629, 30391.9538, 41753.1894, 57361.5251, 78804.6282, 108263.673, 148735.211, 204335.972, 280721.62, 385662.042, 529831.691, 727895.384, 1000000.0], 'trials': 30, 'method': 'ttest', 'D': 5, 'tprs': [0.1, 0.9], 'test_size': 0.2, 'opt': 'CMAES', 'stratify': False, 'thetas': 10, 'a_prob': 0.05}
# {'name': 'mc_strat_ttest_05_40trials_10theta', 'N': [100.0, 137.38238, 188.739182, 259.29438, 356.224789, 489.390092, 672.335754, 923.670857, 1268.961, 1743.32882, 2395.02662, 3290.34456, 4520.35366, 6210.16942, 8531.67852, 11721.023, 16102.6203, 22122.1629, 30391.9538, 41753.1894, 57361.5251, 78804.6282, 108263.673, 148735.211, 204335.972, 280721.62, 385662.042, 529831.691, 727895.384, 1000000.0], 'trials': 30, 'method': 'ttest', 'D': 5, 'tprs': [0.1, 0.9], 'test_size': 0.2, 'opt': 'CMAES', 'stratify': True, 'thetas': 10, 'a_prob': 0.05}
